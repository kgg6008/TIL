# %%
import numpy as np

# %%
# numpy version
np.__version__
# Out:
# '1.17.4'

# %%
# make 2d array
my_arr = np.array([[10, 20, 30], [40, 50, 60]])

# %%
print(my_arr)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
# type
type(my_arr)
# Out:
# numpy.ndarray

# %%
my_arr[0][2]
# Out:
# 30

# %%
# Built-in function
np.sum(my_arr)
# Out:
# 210

# %%
# plot by matplotlib
import matplotlib.pyplot as plt

# %%
# plot linear graph
plt.plot([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
plt.show()

# %%
# plot scatter
plt.scatter([1, 2, 3, 4, 5], [1, 4, 9, 16, 25])
plt.show()

# %%
# plot scatter with numpy
x = np.random.randn(1000)
y = np.random.randn(1000)
plt.scatter(x, y)
plt.show()
