# %% [markdown]
# # RNN

# %%
import numpy as np
class RNN:
    def __init__(self, Wx, Wh, b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None
    
    def forward(self, x, h_prev):
        Wx, Wh, b = self.params
        t = np.matmul(h_prev, Wh) + np.matmul(x, Wx) + b
        h_next = np.tanh(t)
        
        self.cache = (x, h_prev, h_next)
        
        return h_next
    
    def backward(self, dh_next):
        Wx, Wh, b = self.params
        x, h_prev, h_next = self.cache
        
        dt = dh_next * (1 - h_next ** 2)
        db = np.sum(dt, axis=0)
        dWh = np.matmul(h_prev.T, dt)
        dh_prev = np.matmul(dt, Wh.T)
        dWx = np.matmul(x.T,dt)
        dx = np.matmul(dt, Wx.T)
        
        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db
        
        return dx, dh_prev

# %%
class TimeRNN:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None
        
        self.h, self.dh = None, None
        self.stateful = stateful
        
    def set_State(self, h):
        self.h = h
        
    def reset_state(self):
        self.h = None
        
    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        D, H = Wx.shape
        
        self.layers = []
        hs = np.empty((N, T, H), dtype='f')
        
        if not self.stateful or self.h is None:
            self.h = np.zeros((N,H), dtype='f')
        
        for t in range(T):
            layer = RNN(*self.params)
            self.h = layer.forward(xs[:, t, :], self.h)
            hs[:, t, :] = self.h
            self.layers.append(layer)
        return hs
        
    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D, H = Wx.shape
        
        dxs = np.empty((N, T, D), dtype='f')
        dh =0
        grads = [0, 0, 0]

        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh = layer.backward(dhs[:, t, :] + dh)
            dxs[:, t, :] = dx
            
            for i, grad in enumerate(layer.grads):
                grads[i] += grad
                
        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
        self.dh = dh
        
        return dxs

# %%
from common.time_layers import *
class SimpleRnnlm:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn
        
        embed_W = (rn(V, D) / 100).astype('f')
        rnn_Wx = (rn(D, H) / np.sqrt(D)).astype('f')
        rnn_Wh = (rn(H, H) / np.sqrt(H)).astype('f')
        rnn_b = np.zeros(H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')
        
        self.layers = [
            TimeEmbedding(embed_W),
            TimeRNN(rnn_Wx, rnn_Wh, rnn_b, stateful=True),
            TimeAffine(affine_W, affine_b),
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.rnn_layer = self.layers[1]
        
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads
            
    def forward(self, xs, ts):
        for layer in self.layers:
            xs = layer.forward(xs)
        loss = self.loss_layer.forward(xs,ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout
    
    def reset_state(self):
        self.rnn_layer.reset_state()

# %%
# %matplotlib inline
from dataset import ptb
from common.optimizer import SGD
import matplotlib.pyplot as plt

batch_size = 10
wordvec_size = 100
hidden_size = 100
time_size = 5
lr = 0.1
max_epoch = 150

corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 1000
corpus = corpus[:corpus_size]
vocab_size = int(max(corpus) + 1)

xs = corpus[:-1]
ts = corpus[1:]
data_size = len(xs)

print('말뭉치 크기 : %d, 어휘 수 : %d' %(corpus_size, vocab_size))

max_iters = data_size // (batch_size * time_size)
time_idx = 0
total_loss = 0 
loss_count = 0
ppl_list = []

model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)

jump = (corpus_size - 1) // batch_size
offsets = [i * jump for i in range(batch_size)]

for epoch in range(max_epoch):
    for iter in range(max_iters) :
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, t] = xs[(offset + time_idx) % data_size]
                batch_t[i, t] = ts[(offset + time_idx) % data_size]
            time_idx += 1
            
        loss = model.forward(batch_x, batch_t)
        model.backward()
        optimizer.update(model.params, model.grads)
        total_loss += loss
        loss_count += 1
        
    ppl = np.exp(total_loss / loss_count)
    print('| 에폭 %d | 퍼플렉서티 %.2f' % (epoch+1, ppl))
    ppl_list.append(float(ppl))
    total_loss, loss_count = 0, 0
# Out:
# 말뭉치 크기 : 1000, 어휘 수 : 418
# | 에폭 1 | 퍼플렉서티 400.20
# | 에폭 2 | 퍼플렉서티 284.68
# | 에폭 3 | 퍼플렉서티 229.29
# | 에폭 4 | 퍼플렉서티 216.63
# | 에폭 5 | 퍼플렉서티 207.03
# | 에폭 6 | 퍼플렉서티 203.23
# | 에폭 7 | 퍼플렉서티 198.81
# | 에폭 8 | 퍼플렉서티 196.09
# | 에폭 9 | 퍼플렉서티 190.92
# | 에폭 10 | 퍼플렉서티 191.65
# | 에폭 11 | 퍼플렉서티 187.21
# | 에폭 12 | 퍼플렉서티 190.88
# | 에폭 13 | 퍼플렉서티 187.93
# | 에폭 14 | 퍼플렉서티 188.89
# | 에폭 15 | 퍼플렉서티 188.98
# | 에폭 16 | 퍼플렉서티 185.77
# | 에폭 17 | 퍼플렉서티 182.53
# | 에폭 18 | 퍼플렉서티 181.81
# | 에폭 19 | 퍼플렉서티 183.36
# | 에폭 20 | 퍼플렉서티 182.89
# | 에폭 21 | 퍼플렉서티 182.41
# | 에폭 22 | 퍼플렉서티 177.25
# | 에폭 23 | 퍼플렉서티 174.56
# | 에폭 24 | 퍼플렉서티 175.68
# | 에폭 25 | 퍼플렉서티 172.87
# | 에폭 26 | 퍼플렉서티 172.70
# | 에폭 27 | 퍼플렉서티 165.95
# | 에폭 28 | 퍼플렉서티 164.60
# | 에폭 29 | 퍼플렉서티 164.57
# | 에폭 30 | 퍼플렉서티 156.17
# | 에폭 31 | 퍼플렉서티 158.73
# | 에폭 32 | 퍼플렉서티 151.88
# | 에폭 33 | 퍼플렉서티 151.83
# | 에폭 34 | 퍼플렉서티 147.61
# | 에폭 35 | 퍼플렉서티 145.14
# | 에폭 36 | 퍼플렉서티 139.25
# | 에폭 37 | 퍼플렉서티 133.69
# | 에폭 38 | 퍼플렉서티 131.24
# | 에폭 39 | 퍼플렉서티 124.78
# | 에폭 40 | 퍼플렉서티 120.73
# | 에폭 41 | 퍼플렉서티 120.91
# | 에폭 42 | 퍼플렉서티 113.30
# | 에폭 43 | 퍼플렉서티 109.63
# | 에폭 44 | 퍼플렉서티 103.01
# | 에폭 45 | 퍼플렉서티 98.84
# | 에폭 46 | 퍼플렉서티 97.53
# | 에폭 47 | 퍼플렉서티 92.14
# | 에폭 48 | 퍼플렉서티 87.85
# | 에폭 49 | 퍼플렉서티 83.45
# | 에폭 50 | 퍼플렉서티 80.85
# | 에폭 51 | 퍼플렉서티 77.19
# | 에폭 52 | 퍼플렉서티 75.74
# | 에폭 53 | 퍼플렉서티 70.02
# | 에폭 54 | 퍼플렉서티 67.73
# | 에폭 55 | 퍼플렉서티 65.16
# | 에폭 56 | 퍼플렉서티 61.44
# | 에폭 57 | 퍼플렉서티 58.31
# | 에폭 58 | 퍼플렉서티 54.44
# | 에폭 59 | 퍼플렉서티 50.34
# | 에폭 60 | 퍼플렉서티 49.02
# | 에폭 61 | 퍼플렉서티 47.69
# | 에폭 62 | 퍼플렉서티 45.17
# | 에폭 63 | 퍼플렉서티 41.66
# | 에폭 64 | 퍼플렉서티 39.34
# | 에폭 65 | 퍼플렉서티 37.88
# | 에폭 66 | 퍼플렉서티 35.06
# | 에폭 67 | 퍼플렉서티 34.05
# | 에폭 68 | 퍼플렉서티 31.57
# | 에폭 69 | 퍼플렉서티 30.59
# | 에폭 70 | 퍼플렉서티 29.79
# | 에폭 71 | 퍼플렉서티 27.71
# | 에폭 72 | 퍼플렉서티 26.36
# | 에폭 73 | 퍼플렉서티 24.47
# | 에폭 74 | 퍼플렉서티 22.26
# | 에폭 75 | 퍼플렉서티 21.72
# | 에폭 76 | 퍼플렉서티 20.12
# | 에폭 77 | 퍼플렉서티 20.35
# | 에폭 78 | 퍼플렉서티 19.11
# | 에폭 79 | 퍼플렉서티 17.88
# | 에폭 80 | 퍼플렉서티 16.60
# | 에폭 81 | 퍼플렉서티 15.82
# | 에폭 82 | 퍼플렉서티 14.93
# | 에폭 83 | 퍼플렉서티 14.47
# | 에폭 84 | 퍼플렉서티 14.02
# | 에폭 85 | 퍼플렉서티 12.87
# | 에폭 86 | 퍼플렉서티 12.16
# | 에폭 87 | 퍼플렉서티 11.63
# | 에폭 88 | 퍼플렉서티 11.47
# | 에폭 89 | 퍼플렉서티 10.07
# | 에폭 90 | 퍼플렉서티 9.83
# | 에폭 91 | 퍼플렉서티 9.87
# | 에폭 92 | 퍼플렉서티 9.06
# | 에폭 93 | 퍼플렉서티 8.37
# | 에폭 94 | 퍼플렉서티 8.44
# | 에폭 95 | 퍼플렉서티 7.66
# | 에폭 96 | 퍼플렉서티 7.22
# | 에폭 97 | 퍼플렉서티 6.81
# | 에폭 98 | 퍼플렉서티 6.78
# | 에폭 99 | 퍼플렉서티 6.51
# | 에폭 100 | 퍼플렉서티 6.29
# | 에폭 101 | 퍼플렉서티 6.00
# | 에폭 102 | 퍼플렉서티 5.64
# | 에폭 103 | 퍼플렉서티 5.44
# | 에폭 104 | 퍼플렉서티 5.19
# | 에폭 105 | 퍼플렉서티 5.16
# | 에폭 106 | 퍼플렉서티 4.61
# | 에폭 107 | 퍼플렉서티 4.48
# | 에폭 108 | 퍼플렉서티 4.53
# | 에폭 109 | 퍼플렉서티 4.20
# | 에폭 110 | 퍼플렉서티 4.47
# | 에폭 111 | 퍼플렉서티 3.88
# | 에폭 112 | 퍼플렉서티 3.82
# | 에폭 113 | 퍼플렉서티 3.57
# | 에폭 114 | 퍼플렉서티 3.54
# | 에폭 115 | 퍼플렉서티 3.34
# | 에폭 116 | 퍼플렉서티 3.18
# | 에폭 117 | 퍼플렉서티 3.10
# | 에폭 118 | 퍼플렉서티 3.00
# | 에폭 119 | 퍼플렉서티 2.92
# | 에폭 120 | 퍼플렉서티 2.87
# | 에폭 121 | 퍼플렉서티 2.88
# | 에폭 122 | 퍼플렉서티 2.75
# | 에폭 123 | 퍼플렉서티 2.62
# | 에폭 124 | 퍼플렉서티 2.55
# | 에폭 125 | 퍼플렉서티 2.44
# | 에폭 126 | 퍼플렉서티 2.39
# | 에폭 127 | 퍼플렉서티 2.28
# | 에폭 128 | 퍼플렉서티 2.24
# | 에폭 129 | 퍼플렉서티 2.19
# | 에폭 130 | 퍼플렉서티 2.11
# | 에폭 131 | 퍼플렉서티 2.10
# | 에폭 132 | 퍼플렉서티 2.07
# | 에폭 133 | 퍼플렉서티 1.97
# | 에폭 134 | 퍼플렉서티 2.01
# | 에폭 135 | 퍼플렉서티 2.02
# | 에폭 136 | 퍼플렉서티 1.92
# | 에폭 137 | 퍼플렉서티 1.92
# | 에폭 138 | 퍼플렉서티 1.88
# | 에폭 139 | 퍼플렉서티 1.82
# | 에폭 140 | 퍼플렉서티 1.75
# | 에폭 141 | 퍼플렉서티 1.71
# | 에폭 142 | 퍼플렉서티 1.68
# | 에폭 143 | 퍼플렉서티 1.74
# | 에폭 144 | 퍼플렉서티 1.85
# | 에폭 145 | 퍼플렉서티 1.65
# | 에폭 146 | 퍼플렉서티 1.63
# | 에폭 147 | 퍼플렉서티 1.63
# | 에폭 148 | 퍼플렉서티 1.57
# | 에폭 149 | 퍼플렉서티 1.53
# | 에폭 150 | 퍼플렉서티 1.50

# %%
plt.plot(ppl_list)

# %%
from common.trainer import RnnlmTrainer

model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)
trainer.fit(xs, ts, max_epoch, batch_size, time_size)
# Out:
# | 에폭 1 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 417.45
# | 에폭 2 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 400.65
# | 에폭 3 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 299.87
# | 에폭 4 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 231.28
# | 에폭 5 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 214.52
# | 에폭 6 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 211.18
# | 에폭 7 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 201.65
# | 에폭 8 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 201.50
# | 에폭 9 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 196.27
# | 에폭 10 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 191.39
# | 에폭 11 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 192.32
# | 에폭 12 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 189.61
# | 에폭 13 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 193.60
# | 에폭 14 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 186.41
# | 에폭 15 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 185.92
# | 에폭 16 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 189.15
# | 에폭 17 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 187.91
# | 에폭 18 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 182.95
# | 에폭 19 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 178.73
# | 에폭 20 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 182.65
# | 에폭 21 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 177.70
# | 에폭 22 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 177.35
# | 에폭 23 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 179.24
# | 에폭 24 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 174.95
# | 에폭 25 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 171.89
# | 에폭 26 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 171.24
# | 에폭 27 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 169.70
# | 에폭 28 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 171.53
# | 에폭 29 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 166.74
# | 에폭 30 |  반복 1 / 19 | 시간 0[s] | 퍼플렉서티 162.58
# | 에폭 31 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 159.97
# | 에폭 32 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 155.83
# | 에폭 33 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 157.02
# | 에폭 34 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 153.94
# | 에폭 35 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 150.21
# | 에폭 36 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 147.36
# | 에폭 37 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 143.86
# | 에폭 38 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 139.07
# | 에폭 39 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 136.46
# | 에폭 40 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 130.62
# | 에폭 41 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 126.17
# | 에폭 42 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 123.43
# | 에폭 43 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 119.94
# | 에폭 44 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 117.81
# | 에폭 45 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 110.63
# | 에폭 46 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 107.67
# | 에폭 47 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 104.53
# | 에폭 48 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 100.32
# | 에폭 49 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 97.13
# | 에폭 50 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 90.95
# | 에폭 51 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 87.56
# | 에폭 52 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 83.32
# | 에폭 53 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 80.65
# | 에폭 54 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 76.42
# | 에폭 55 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 73.05
# | 에폭 56 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 68.39
# | 에폭 57 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 69.06
# | 에폭 58 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 63.25
# | 에폭 59 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 60.06
# | 에폭 60 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 55.48
# | 에폭 61 |  반복 1 / 19 | 시간 1[s] | 퍼플렉서티 52.23
# | 에폭 62 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 49.54
# | 에폭 63 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 48.28
# | 에폭 64 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 44.96
# | 에폭 65 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 42.12
# | 에폭 66 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 39.08
# | 에폭 67 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 38.24
# | 에폭 68 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 35.99
# | 에폭 69 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 33.78
# | 에폭 70 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 31.67
# | 에폭 71 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 29.44
# | 에폭 72 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 27.34
# | 에폭 73 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 26.32
# | 에폭 74 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 25.32
# | 에폭 75 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 23.21
# | 에폭 76 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 22.32
# | 에폭 77 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 21.20
# | 에폭 78 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 20.31
# | 에폭 79 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 18.40
# | 에폭 80 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 17.53
# | 에폭 81 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 16.39
# | 에폭 82 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 16.17
# | 에폭 83 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 15.32
# | 에폭 84 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 14.56
# | 에폭 85 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 13.39
# | 에폭 86 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 13.23
# | 에폭 87 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 12.31
# | 에폭 88 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 11.31
# | 에폭 89 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 11.06
# | 에폭 90 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 10.46
# | 에폭 91 |  반복 1 / 19 | 시간 2[s] | 퍼플렉서티 9.73
# | 에폭 92 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 9.75
# | 에폭 93 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 8.94
# | 에폭 94 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 8.59
# | 에폭 95 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 7.84
# | 에폭 96 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 7.89
# | 에폭 97 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 7.21
# | 에폭 98 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 6.73
# | 에폭 99 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 6.46
# | 에폭 100 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 6.08
# | 에폭 101 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 5.86
# | 에폭 102 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 5.63
# | 에폭 103 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 5.60
# | 에폭 104 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 5.53
# | 에폭 105 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 5.11
# | 에폭 106 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 4.80
# | 에폭 107 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 4.71
# | 에폭 108 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 4.54
# | 에폭 109 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 4.46
# | 에폭 110 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 4.18
# | 에폭 111 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 4.17
# | 에폭 112 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 3.86
# | 에폭 113 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 3.79
# | 에폭 114 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 3.62
# | 에폭 115 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 3.54
# | 에폭 116 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 3.37
# | 에폭 117 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 3.29
# | 에폭 118 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 3.15
# | 에폭 119 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 3.10
# | 에폭 120 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 2.85
# | 에폭 121 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 2.75
# | 에폭 122 |  반복 1 / 19 | 시간 3[s] | 퍼플렉서티 2.88
# | 에폭 123 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.67
# | 에폭 124 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.54
# | 에폭 125 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.56
# | 에폭 126 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.39
# | 에폭 127 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.48
# | 에폭 128 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.32
# | 에폭 129 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.23
# | 에폭 130 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.17
# | 에폭 131 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.20
# | 에폭 132 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.15
# | 에폭 133 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.05
# | 에폭 134 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 2.07
# | 에폭 135 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.91
# | 에폭 136 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.88
# | 에폭 137 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.88
# | 에폭 138 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.82
# | 에폭 139 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.78
# | 에폭 140 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.77
# | 에폭 141 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.86
# | 에폭 142 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.69
# | 에폭 143 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.64
# | 에폭 144 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.63
# | 에폭 145 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.61
# | 에폭 146 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.59
# | 에폭 147 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.54
# | 에폭 148 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.57
# | 에폭 149 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.56
# | 에폭 150 |  반복 1 / 19 | 시간 4[s] | 퍼플렉서티 1.54
