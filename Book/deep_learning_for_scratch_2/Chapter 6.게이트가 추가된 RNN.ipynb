# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

N = 2
H = 3
T = 20

dh = np.ones((N, H))
np.random.seed(3)
Wh = np.random.randn(H, H)

norm_list = []
for t in range(T):
    dh = np.matmul(dh, Wh.T)
    norm = np.sqrt(np.sum(dh**2)) / N
    norm_list.append(norm)

# %%
plt.plot(norm_list)

# %%
dh = np.ones((N, H))
np.random.seed(3)
Wh = np.random.randn(H, H) * 0.5

norm_list = []
for t in range(T):
    dh = np.matmul(dh, Wh.T)
    norm = np.sqrt(np.sum(dh**2)) / N
    norm_list.append(norm)
    
plt.plot(norm_list)

# %%
dW1 = np.random.rand(3, 3)*10
dW2 = np.random.rand(3, 3)*10
grads = [dW1, dW2]
max_norm = 5.

def clip_grads(grads, max_norm):
    total_norm = 0
    for grad in grads:
        total_norm += np.sum(grad ** 2)
    total_norm = np.sqrt(total_norm)
    
    rate = max_norm / (total_norm + 1e-6)
    if rate < 1:
        for grad in grads:
            grad *= rate

# %%
from common.functions import sigmoid
class LSTM:
    def __init__(self, Wx, Wh, b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None
        
    def forward(self, x, h_prev, c_prev):
        Wx, Wh, b = self.params
        N, H = h_prev.shape
        
        A = np.matmul(x, Wx) + np.matmul(h_prev, Wh) + b
        
        f = A[:, :H]
        g = A[:, H : 2*H]
        i = A[:, 2*H : 3*H]
        o = A[:, 3*H:]
        
        f = sigmoid(f)
        g = np.tanh(g)
        i = sigmoid(i)
        o = sigmoid(o)
        
        c_next = f*c_prev + g*i
        h_next = o * np.tanh(c_next)
        
        self.cache = (x, h_prev, c_prev, i, f, g, o, c_next)
        return h_next, c_next
    
    def backward(self, dh_next, dc_next):
        Wx, Wh, b = self.params
        x, h_prev, c_prev, i, f, g, o, c_next = self.cache

        tanh_c_next = np.tanh(c_next)

        ds = dc_next + (dh_next * o) * (1 - tanh_c_next ** 2)

        dc_prev = ds * f

        di = ds * g
        df = ds * c_prev
        do = dh_next * tanh_c_next
        dg = ds * i

        di *= i * (1 - i)
        df *= f * (1 - f)
        do *= o * (1 - o)
        dg *= (1 - g ** 2)

        dA = np.hstack((df, dg, di, do))

        dWh = np.dot(h_prev.T, dA)
        dWx = np.dot(x.T, dA)
        db = dA.sum(axis=0)

        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db

        dx = np.dot(dA, Wx.T)
        dh_prev = np.dot(dA, Wh.T)

        return dx, dh_prev, dc_prev

# %%
class TimeLSTM:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None
        self.h, self.c = None, None
        self.dh = None
        self.stateful = stateful
        
    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        H = Wh.shape[0]
        
        self.layers = []
        hs = np.empty((N, T, H), dtype='f')
        
        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')
        if not self.stateful or self.c is None:
            self.c = np.zeros((N, H), dtype='f')
            
        for t in range(T):
            layer = LSTM(*self.params)
            self.h, self.c = layer.forward(xs[:,t, :], self.h, self.c)
            hs[:, t, :] = self.h
            
            self.layers.append(layer)
            
        return hs
    
    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D = Wx.shape[0]
        
        dxs = np.empty((N, T, D), dtype='f')
        dh, dc = 0, 0
        
        grads = [0, 0, 0]
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh, dc = layer.backward(dhs[:, t, :] + dh, dc)
            dxs[:, t, :] = dx
            for i, grad in enumerate(layer.grads):
                grads[i] += grad
            
        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
        self.dh = dh
        return dxs
    
    def set_state(self, h, c= None):
        self.h, self.c = h, c
        
    def reset_state(self):
        self.h, self.c = None, None

# %%
from common.time_layers import *
import pickle

class Rnnlm:
    def __init__(self, vocab_size=10000, wordvec_size=100, hidden_size=100):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn
        
        embed_W = (rn(V, D)/100).astype('f')
        lstm_Wx = (rn(D, 4*H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4*H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4*H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')
        
        self.layers = [
            TimeEmbedding(embed_W),
            TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True),
            TimeAffine(affine_W, affine_b),
        ]
        
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layer = self.layers[1]
        
        self.params, self.grads =[], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads
            
    def predict(self, xs):
        for layer in self.layers:
            xs = layer.forward(xs)
        return xs
    
    def forward(self, xs, ts):
        score = self.predict(xs)
        loss = self.loss_layer.forward(score, ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout
    
    def reset_state(self):
        self.lstm_layer.reset_state()
        
    def save_params(self, file_name = 'Rnnlm.pkl'):
        with open(file_name, 'wb') as f:
            pickle.dump(self.params, f)

    def load_params(self, file_name = 'Rnnlm.pkl'):
        with open(file_name, 'rb') as f:
            self.params = pickle.load(f)

# %%
from common.optimizer import SGD
from common.trainer import RnnlmTrainer
from common.util import eval_perplexity
from dataset import ptb

batch_size = 20
wordvec_size = 100
hidden_size = 100
time_size = 35
lr = 20.0
max_epoch = 5
max_grad = .25

corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_test, _, _ = ptb.load_data('test')
vocab_size = len(word_to_id)

xs = corpus[: -1]
ts = corpus[1 :]

model = Rnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

trainer.fit(xs, ts, max_epoch, batch_size, time_size, max_grad, eval_interval=20)
trainer.plot(ylim=(0, 500))

model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('test perplexity: ', ppl_test)

model.save_params()
# Out:
# | 에폭 1 |  반복 1 / 1327 | 시간 0[s] | 퍼플렉서티 9999.62
# | 에폭 1 |  반복 21 / 1327 | 시간 3[s] | 퍼플렉서티 2977.73
# | 에폭 1 |  반복 41 / 1327 | 시간 6[s] | 퍼플렉서티 1226.79
# | 에폭 1 |  반복 61 / 1327 | 시간 10[s] | 퍼플렉서티 973.36
# | 에폭 1 |  반복 81 / 1327 | 시간 13[s] | 퍼플렉서티 786.07
# | 에폭 1 |  반복 101 / 1327 | 시간 17[s] | 퍼플렉서티 644.28
# | 에폭 1 |  반복 121 / 1327 | 시간 20[s] | 퍼플렉서티 655.39
# | 에폭 1 |  반복 141 / 1327 | 시간 24[s] | 퍼플렉서티 600.27
# | 에폭 1 |  반복 161 / 1327 | 시간 27[s] | 퍼플렉서티 588.57
# | 에폭 1 |  반복 181 / 1327 | 시간 31[s] | 퍼플렉서티 591.14
# | 에폭 1 |  반복 201 / 1327 | 시간 34[s] | 퍼플렉서티 502.29
# | 에폭 1 |  반복 221 / 1327 | 시간 38[s] | 퍼플렉서티 498.84
# | 에폭 1 |  반복 241 / 1327 | 시간 41[s] | 퍼플렉서티 444.28
# | 에폭 1 |  반복 261 / 1327 | 시간 45[s] | 퍼플렉서티 464.20
# | 에폭 1 |  반복 281 / 1327 | 시간 49[s] | 퍼플렉서티 459.63
# | 에폭 1 |  반복 301 / 1327 | 시간 52[s] | 퍼플렉서티 384.31
# | 에폭 1 |  반복 321 / 1327 | 시간 56[s] | 퍼플렉서티 341.83
# | 에폭 1 |  반복 341 / 1327 | 시간 60[s] | 퍼플렉서티 403.59
# | 에폭 1 |  반복 361 / 1327 | 시간 63[s] | 퍼플렉서티 406.67
# | 에폭 1 |  반복 381 / 1327 | 시간 67[s] | 퍼플렉서티 330.69
# | 에폭 1 |  반복 401 / 1327 | 시간 71[s] | 퍼플렉서티 353.39
# | 에폭 1 |  반복 421 / 1327 | 시간 75[s] | 퍼플렉서티 341.23
# | 에폭 1 |  반복 441 / 1327 | 시간 78[s] | 퍼플렉서티 326.13
# | 에폭 1 |  반복 461 / 1327 | 시간 82[s] | 퍼플렉서티 329.39
# | 에폭 1 |  반복 481 / 1327 | 시간 86[s] | 퍼플렉서티 305.65
# | 에폭 1 |  반복 501 / 1327 | 시간 89[s] | 퍼플렉서티 314.96
# | 에폭 1 |  반복 521 / 1327 | 시간 93[s] | 퍼플렉서티 304.54
# | 에폭 1 |  반복 541 / 1327 | 시간 96[s] | 퍼플렉서티 314.87
# | 에폭 1 |  반복 561 / 1327 | 시간 100[s] | 퍼플렉서티 288.37
# | 에폭 1 |  반복 581 / 1327 | 시간 104[s] | 퍼플렉서티 256.62
# | 에폭 1 |  반복 601 / 1327 | 시간 107[s] | 퍼플렉서티 335.10
# | 에폭 1 |  반복 621 / 1327 | 시간 111[s] | 퍼플렉서티 307.74
# | 에폭 1 |  반복 641 / 1327 | 시간 115[s] | 퍼플렉서티 280.17
# | 에폭 1 |  반복 661 / 1327 | 시간 118[s] | 퍼플렉서티 267.76
# | 에폭 1 |  반복 681 / 1327 | 시간 122[s] | 퍼플렉서티 227.05
# | 에폭 1 |  반복 701 / 1327 | 시간 126[s] | 퍼플렉서티 250.36
# | 에폭 1 |  반복 721 / 1327 | 시간 129[s] | 퍼플렉서티 257.23
# | 에폭 1 |  반복 741 / 1327 | 시간 133[s] | 퍼플렉서티 219.00
# | 에폭 1 |  반복 761 / 1327 | 시간 136[s] | 퍼플렉서티 232.72
# | 에폭 1 |  반복 781 / 1327 | 시간 140[s] | 퍼플렉서티 217.60
# | 에폭 1 |  반복 801 / 1327 | 시간 144[s] | 퍼플렉서티 239.84
# | 에폭 1 |  반복 821 / 1327 | 시간 147[s] | 퍼플렉서티 224.68
# | 에폭 1 |  반복 841 / 1327 | 시간 151[s] | 퍼플렉서티 227.10
# | 에폭 1 |  반복 861 / 1327 | 시간 155[s] | 퍼플렉서티 220.29
# | 에폭 1 |  반복 881 / 1327 | 시간 158[s] | 퍼플렉서티 205.57
# | 에폭 1 |  반복 901 / 1327 | 시간 162[s] | 퍼플렉서티 255.70
# | 에폭 1 |  반복 921 / 1327 | 시간 166[s] | 퍼플렉서티 225.46
# | 에폭 1 |  반복 941 / 1327 | 시간 169[s] | 퍼플렉서티 232.66
# | 에폭 1 |  반복 961 / 1327 | 시간 173[s] | 퍼플렉서티 243.60
# | 에폭 1 |  반복 981 / 1327 | 시간 176[s] | 퍼플렉서티 228.44
# | 에폭 1 |  반복 1001 / 1327 | 시간 180[s] | 퍼플렉서티 194.38
# | 에폭 1 |  반복 1021 / 1327 | 시간 184[s] | 퍼플렉서티 226.45
# | 에폭 1 |  반복 1041 / 1327 | 시간 187[s] | 퍼플렉서티 207.04
# | 에폭 1 |  반복 1061 / 1327 | 시간 191[s] | 퍼플렉서티 197.89
# | 에폭 1 |  반복 1081 / 1327 | 시간 195[s] | 퍼플렉서티 168.84
# | 에폭 1 |  반복 1101 / 1327 | 시간 198[s] | 퍼플렉서티 191.46
# | 에폭 1 |  반복 1121 / 1327 | 시간 202[s] | 퍼플렉서티 226.88
# | 에폭 1 |  반복 1141 / 1327 | 시간 206[s] | 퍼플렉서티 206.91
# | 에폭 1 |  반복 1161 / 1327 | 시간 209[s] | 퍼플렉서티 198.57
# | 에폭 1 |  반복 1181 / 1327 | 시간 213[s] | 퍼플렉서티 189.47
# | 에폭 1 |  반복 1201 / 1327 | 시간 217[s] | 퍼플렉서티 162.59
# | 에폭 1 |  반복 1221 / 1327 | 시간 220[s] | 퍼플렉서티 156.92
# | 에폭 1 |  반복 1241 / 1327 | 시간 224[s] | 퍼플렉서티 186.12
# | 에폭 1 |  반복 1261 / 1327 | 시간 228[s] | 퍼플렉서티 170.72
# | 에폭 1 |  반복 1281 / 1327 | 시간 231[s] | 퍼플렉서티 178.84
# | 에폭 1 |  반복 1301 / 1327 | 시간 235[s] | 퍼플렉서티 220.12
# | 에폭 1 |  반복 1321 / 1327 | 시간 239[s] | 퍼플렉서티 208.33
# | 에폭 2 |  반복 1 / 1327 | 시간 240[s] | 퍼플렉서티 223.55
# | 에폭 2 |  반복 21 / 1327 | 시간 243[s] | 퍼플렉서티 203.49
# | 에폭 2 |  반복 41 / 1327 | 시간 247[s] | 퍼플렉서티 189.23
# | 에폭 2 |  반복 61 / 1327 | 시간 251[s] | 퍼플렉서티 175.78
# | 에폭 2 |  반복 81 / 1327 | 시간 254[s] | 퍼플렉서티 159.31
# | 에폭 2 |  반복 101 / 1327 | 시간 258[s] | 퍼플렉서티 152.09
# | 에폭 2 |  반복 121 / 1327 | 시간 262[s] | 퍼플렉서티 160.08
# | 에폭 2 |  반복 141 / 1327 | 시간 265[s] | 퍼플렉서티 177.62
# | 에폭 2 |  반복 161 / 1327 | 시간 269[s] | 퍼플렉서티 191.78
# | 에폭 2 |  반복 181 / 1327 | 시간 273[s] | 퍼플렉서티 200.86
# | 에폭 2 |  반복 201 / 1327 | 시간 276[s] | 퍼플렉서티 184.50
# | 에폭 2 |  반복 221 / 1327 | 시간 280[s] | 퍼플렉서티 184.79
# | 에폭 2 |  반복 241 / 1327 | 시간 284[s] | 퍼플렉서티 176.17
# | 에폭 2 |  반복 261 / 1327 | 시간 287[s] | 퍼플렉서티 184.75
# | 에폭 2 |  반복 281 / 1327 | 시간 291[s] | 퍼플렉서티 185.54
# | 에폭 2 |  반복 301 / 1327 | 시간 295[s] | 퍼플렉서티 167.50
# | 에폭 2 |  반복 321 / 1327 | 시간 299[s] | 퍼플렉서티 136.57
# | 에폭 2 |  반복 341 / 1327 | 시간 302[s] | 퍼플렉서티 171.43
# | 에폭 2 |  반복 361 / 1327 | 시간 306[s] | 퍼플렉서티 196.90
# | 에폭 2 |  반복 381 / 1327 | 시간 310[s] | 퍼플렉서티 152.15
# | 에폭 2 |  반복 401 / 1327 | 시간 313[s] | 퍼플렉서티 168.66
# | 에폭 2 |  반복 421 / 1327 | 시간 317[s] | 퍼플렉서티 155.43
# | 에폭 2 |  반복 441 / 1327 | 시간 321[s] | 퍼플렉서티 162.91
# | 에폭 2 |  반복 461 / 1327 | 시간 324[s] | 퍼플렉서티 155.41
# | 에폭 2 |  반복 481 / 1327 | 시간 328[s] | 퍼플렉서티 154.39
# | 에폭 2 |  반복 501 / 1327 | 시간 332[s] | 퍼플렉서티 168.47
# | 에폭 2 |  반복 521 / 1327 | 시간 336[s] | 퍼플렉서티 173.68
# | 에폭 2 |  반복 541 / 1327 | 시간 339[s] | 퍼플렉서티 174.57
# | 에폭 2 |  반복 561 / 1327 | 시간 343[s] | 퍼플렉서티 153.65
# | 에폭 2 |  반복 581 / 1327 | 시간 347[s] | 퍼플렉서티 136.69
# | 에폭 2 |  반복 601 / 1327 | 시간 351[s] | 퍼플렉서티 188.32
# | 에폭 2 |  반복 621 / 1327 | 시간 355[s] | 퍼플렉서티 180.90
# | 에폭 2 |  반복 641 / 1327 | 시간 358[s] | 퍼플렉서티 165.02
# | 에폭 2 |  반복 661 / 1327 | 시간 362[s] | 퍼플렉서티 153.16
# | 에폭 2 |  반복 681 / 1327 | 시간 365[s] | 퍼플렉서티 127.96
# | 에폭 2 |  반복 701 / 1327 | 시간 369[s] | 퍼플렉서티 151.07
# | 에폭 2 |  반복 721 / 1327 | 시간 373[s] | 퍼플렉서티 159.13
# | 에폭 2 |  반복 741 / 1327 | 시간 377[s] | 퍼플렉서티 132.95
# | 에폭 2 |  반복 761 / 1327 | 시간 380[s] | 퍼플렉서티 130.59
# | 에폭 2 |  반복 781 / 1327 | 시간 384[s] | 퍼플렉서티 134.18
# | 에폭 2 |  반복 801 / 1327 | 시간 388[s] | 퍼플렉서티 145.38
# | 에폭 2 |  반복 821 / 1327 | 시간 391[s] | 퍼플렉서티 142.98
# | 에폭 2 |  반복 841 / 1327 | 시간 395[s] | 퍼플렉서티 144.85
# | 에폭 2 |  반복 861 / 1327 | 시간 399[s] | 퍼플렉서티 145.45
# | 에폭 2 |  반복 881 / 1327 | 시간 403[s] | 퍼플렉서티 130.26
# | 에폭 2 |  반복 901 / 1327 | 시간 406[s] | 퍼플렉서티 166.28
# | 에폭 2 |  반복 921 / 1327 | 시간 410[s] | 퍼플렉서티 144.61
# | 에폭 2 |  반복 941 / 1327 | 시간 414[s] | 퍼플렉서티 154.22
# | 에폭 2 |  반복 961 / 1327 | 시간 417[s] | 퍼플렉서티 162.92
# | 에폭 2 |  반복 981 / 1327 | 시간 421[s] | 퍼플렉서티 154.76
# | 에폭 2 |  반복 1001 / 1327 | 시간 425[s] | 퍼플렉서티 131.85
# | 에폭 2 |  반복 1021 / 1327 | 시간 429[s] | 퍼플렉서티 155.62
# | 에폭 2 |  반복 1041 / 1327 | 시간 432[s] | 퍼플렉서티 142.28
# | 에폭 2 |  반복 1061 / 1327 | 시간 436[s] | 퍼플렉서티 128.79
# | 에폭 2 |  반복 1081 / 1327 | 시간 440[s] | 퍼플렉서티 109.21
# | 에폭 2 |  반복 1101 / 1327 | 시간 443[s] | 퍼플렉서티 119.07
# | 에폭 2 |  반복 1121 / 1327 | 시간 447[s] | 퍼플렉서티 153.02
# | 에폭 2 |  반복 1141 / 1327 | 시간 451[s] | 퍼플렉서티 140.57
# | 에폭 2 |  반복 1161 / 1327 | 시간 454[s] | 퍼플렉서티 134.15
# | 에폭 2 |  반복 1181 / 1327 | 시간 458[s] | 퍼플렉서티 132.92
# | 에폭 2 |  반복 1201 / 1327 | 시간 462[s] | 퍼플렉서티 111.79
# | 에폭 2 |  반복 1221 / 1327 | 시간 466[s] | 퍼플렉서티 108.74
# | 에폭 2 |  반복 1241 / 1327 | 시간 469[s] | 퍼플렉서티 129.87
# | 에폭 2 |  반복 1261 / 1327 | 시간 473[s] | 퍼플렉서티 123.70
# | 에폭 2 |  반복 1281 / 1327 | 시간 477[s] | 퍼플렉서티 121.48
# | 에폭 2 |  반복 1301 / 1327 | 시간 481[s] | 퍼플렉서티 155.53
# | 에폭 2 |  반복 1321 / 1327 | 시간 484[s] | 퍼플렉서티 151.89
# | 에폭 3 |  반복 1 / 1327 | 시간 486[s] | 퍼플렉서티 157.50
# | 에폭 3 |  반복 21 / 1327 | 시간 489[s] | 퍼플렉서티 143.40
# | 에폭 3 |  반복 41 / 1327 | 시간 493[s] | 퍼플렉서티 133.48
# | 에폭 3 |  반복 61 / 1327 | 시간 497[s] | 퍼플렉서티 127.36
# | 에폭 3 |  반복 81 / 1327 | 시간 500[s] | 퍼플렉서티 115.87
# | 에폭 3 |  반복 101 / 1327 | 시간 504[s] | 퍼플렉서티 105.33
# | 에폭 3 |  반복 121 / 1327 | 시간 508[s] | 퍼플렉서티 115.73
# | 에폭 3 |  반복 141 / 1327 | 시간 512[s] | 퍼플렉서티 125.07
# | 에폭 3 |  반복 161 / 1327 | 시간 515[s] | 퍼플렉서티 140.34
# | 에폭 3 |  반복 181 / 1327 | 시간 519[s] | 퍼플렉서티 150.71
# | 에폭 3 |  반복 201 / 1327 | 시간 523[s] | 퍼플렉서티 140.92
# | 에폭 3 |  반복 221 / 1327 | 시간 527[s] | 퍼플렉서티 140.87
# | 에폭 3 |  반복 241 / 1327 | 시간 530[s] | 퍼플렉서티 133.52
# | 에폭 3 |  반복 261 / 1327 | 시간 534[s] | 퍼플렉서티 138.67
# | 에폭 3 |  반복 281 / 1327 | 시간 538[s] | 퍼플렉서티 139.85
# | 에폭 3 |  반복 301 / 1327 | 시간 541[s] | 퍼플렉서티 123.25
# | 에폭 3 |  반복 321 / 1327 | 시간 545[s] | 퍼플렉서티 101.35
# | 에폭 3 |  반복 341 / 1327 | 시간 549[s] | 퍼플렉서티 124.72
# | 에폭 3 |  반복 361 / 1327 | 시간 552[s] | 퍼플렉서티 151.97
# | 에폭 3 |  반복 381 / 1327 | 시간 556[s] | 퍼플렉서티 113.78
# | 에폭 3 |  반복 401 / 1327 | 시간 560[s] | 퍼플렉서티 130.49
# | 에폭 3 |  반복 421 / 1327 | 시간 564[s] | 퍼플렉서티 114.78
# | 에폭 3 |  반복 441 / 1327 | 시간 567[s] | 퍼플렉서티 122.91
# | 에폭 3 |  반복 461 / 1327 | 시간 571[s] | 퍼플렉서티 116.51
# | 에폭 3 |  반복 481 / 1327 | 시간 575[s] | 퍼플렉서티 117.80
# | 에폭 3 |  반복 501 / 1327 | 시간 579[s] | 퍼플렉서티 129.26
# | 에폭 3 |  반복 521 / 1327 | 시간 582[s] | 퍼플렉서티 136.74
# | 에폭 3 |  반복 541 / 1327 | 시간 586[s] | 퍼플렉서티 136.36
# | 에폭 3 |  반복 561 / 1327 | 시간 590[s] | 퍼플렉서티 117.54
# | 에폭 3 |  반복 581 / 1327 | 시간 594[s] | 퍼플렉서티 105.46
# | 에폭 3 |  반복 601 / 1327 | 시간 597[s] | 퍼플렉서티 148.51
# | 에폭 3 |  반복 621 / 1327 | 시간 601[s] | 퍼플렉서티 141.34
# | 에폭 3 |  반복 641 / 1327 | 시간 605[s] | 퍼플렉서티 128.56
# | 에폭 3 |  반복 661 / 1327 | 시간 609[s] | 퍼플렉서티 119.80
# | 에폭 3 |  반복 681 / 1327 | 시간 612[s] | 퍼플렉서티 99.46
# | 에폭 3 |  반복 701 / 1327 | 시간 616[s] | 퍼플렉서티 117.98
# | 에폭 3 |  반복 721 / 1327 | 시간 620[s] | 퍼플렉서티 125.26
# | 에폭 3 |  반복 741 / 1327 | 시간 623[s] | 퍼플렉서티 107.76
# | 에폭 3 |  반복 761 / 1327 | 시간 627[s] | 퍼플렉서티 103.10
# | 에폭 3 |  반복 781 / 1327 | 시간 631[s] | 퍼플렉서티 103.60
# | 에폭 3 |  반복 801 / 1327 | 시간 635[s] | 퍼플렉서티 114.08
# | 에폭 3 |  반복 821 / 1327 | 시간 639[s] | 퍼플렉서티 114.85
# | 에폭 3 |  반복 841 / 1327 | 시간 642[s] | 퍼플렉서티 115.03
# | 에폭 3 |  반복 861 / 1327 | 시간 646[s] | 퍼플렉서티 119.38
# | 에폭 3 |  반복 881 / 1327 | 시간 650[s] | 퍼플렉서티 105.06
# | 에폭 3 |  반복 901 / 1327 | 시간 654[s] | 퍼플렉서티 131.67
# | 에폭 3 |  반복 921 / 1327 | 시간 657[s] | 퍼플렉서티 116.75
# | 에폭 3 |  반복 941 / 1327 | 시간 661[s] | 퍼플렉서티 126.56
# | 에폭 3 |  반복 961 / 1327 | 시간 665[s] | 퍼플렉서티 131.02
# | 에폭 3 |  반복 981 / 1327 | 시간 669[s] | 퍼플렉서티 124.33
# | 에폭 3 |  반복 1001 / 1327 | 시간 672[s] | 퍼플렉서티 109.22
# | 에폭 3 |  반복 1021 / 1327 | 시간 676[s] | 퍼플렉서티 128.09
# | 에폭 3 |  반복 1041 / 1327 | 시간 680[s] | 퍼플렉서티 118.91
# | 에폭 3 |  반복 1061 / 1327 | 시간 684[s] | 퍼플렉서티 103.01
# | 에폭 3 |  반복 1081 / 1327 | 시간 687[s] | 퍼플렉서티 87.98
# | 에폭 3 |  반복 1101 / 1327 | 시간 691[s] | 퍼플렉서티 93.04
# | 에폭 3 |  반복 1121 / 1327 | 시간 695[s] | 퍼플렉서티 120.65
# | 에폭 3 |  반복 1141 / 1327 | 시간 698[s] | 퍼플렉서티 113.53
# | 에폭 3 |  반복 1161 / 1327 | 시간 702[s] | 퍼플렉서티 107.89
# | 에폭 3 |  반복 1181 / 1327 | 시간 706[s] | 퍼플렉서티 111.10
# | 에폭 3 |  반복 1201 / 1327 | 시간 710[s] | 퍼플렉서티 93.30
# | 에폭 3 |  반복 1221 / 1327 | 시간 713[s] | 퍼플렉서티 88.13
# | 에폭 3 |  반복 1241 / 1327 | 시간 717[s] | 퍼플렉서티 104.62
# | 에폭 3 |  반복 1261 / 1327 | 시간 721[s] | 퍼플렉서티 105.11
# | 에폭 3 |  반복 1281 / 1327 | 시간 724[s] | 퍼플렉서티 99.68
# | 에폭 3 |  반복 1301 / 1327 | 시간 728[s] | 퍼플렉서티 128.14
# | 에폭 3 |  반복 1321 / 1327 | 시간 732[s] | 퍼플렉서티 125.38
# | 에폭 4 |  반복 1 / 1327 | 시간 733[s] | 퍼플렉서티 129.65
# | 에폭 4 |  반복 21 / 1327 | 시간 737[s] | 퍼플렉서티 122.18
# | 에폭 4 |  반복 41 / 1327 | 시간 741[s] | 퍼플렉서티 106.56
# | 에폭 4 |  반복 61 / 1327 | 시간 744[s] | 퍼플렉서티 108.02
# | 에폭 4 |  반복 81 / 1327 | 시간 748[s] | 퍼플렉서티 94.89
# | 에폭 4 |  반복 101 / 1327 | 시간 752[s] | 퍼플렉서티 85.83
# | 에폭 4 |  반복 121 / 1327 | 시간 756[s] | 퍼플렉서티 95.62
# | 에폭 4 |  반복 141 / 1327 | 시간 759[s] | 퍼플렉서티 102.82
# | 에폭 4 |  반복 161 / 1327 | 시간 763[s] | 퍼플렉서티 116.93
# | 에폭 4 |  반복 181 / 1327 | 시간 767[s] | 퍼플렉서티 129.20
# | 에폭 4 |  반복 201 / 1327 | 시간 770[s] | 퍼플렉서티 120.34
# | 에폭 4 |  반복 221 / 1327 | 시간 774[s] | 퍼플렉서티 122.34
# | 에폭 4 |  반복 241 / 1327 | 시간 778[s] | 퍼플렉서티 114.70
# | 에폭 4 |  반복 261 / 1327 | 시간 782[s] | 퍼플렉서티 113.83
# | 에폭 4 |  반복 281 / 1327 | 시간 786[s] | 퍼플렉서티 120.11
# | 에폭 4 |  반복 301 / 1327 | 시간 789[s] | 퍼플렉서티 104.50
# | 에폭 4 |  반복 321 / 1327 | 시간 793[s] | 퍼플렉서티 85.11
# | 에폭 4 |  반복 341 / 1327 | 시간 797[s] | 퍼플렉서티 101.28
# | 에폭 4 |  반복 361 / 1327 | 시간 801[s] | 퍼플렉서티 127.81
# | 에폭 4 |  반복 381 / 1327 | 시간 804[s] | 퍼플렉서티 97.48
# | 에폭 4 |  반복 401 / 1327 | 시간 808[s] | 퍼플렉서티 110.78
# | 에폭 4 |  반복 421 / 1327 | 시간 812[s] | 퍼플렉서티 94.64
# | 에폭 4 |  반복 441 / 1327 | 시간 815[s] | 퍼플렉서티 103.32
# | 에폭 4 |  반복 461 / 1327 | 시간 819[s] | 퍼플렉서티 98.84
# | 에폭 4 |  반복 481 / 1327 | 시간 823[s] | 퍼플렉서티 101.73
# | 에폭 4 |  반복 501 / 1327 | 시간 826[s] | 퍼플렉서티 108.50
# | 에폭 4 |  반복 521 / 1327 | 시간 830[s] | 퍼플렉서티 117.32
# | 에폭 4 |  반복 541 / 1327 | 시간 834[s] | 퍼플렉서티 113.13
# | 에폭 4 |  반복 561 / 1327 | 시간 838[s] | 퍼플렉서티 102.69
# | 에폭 4 |  반복 581 / 1327 | 시간 841[s] | 퍼플렉서티 89.94
# | 에폭 4 |  반복 601 / 1327 | 시간 845[s] | 퍼플렉서티 126.82
# | 에폭 4 |  반복 621 / 1327 | 시간 849[s] | 퍼플렉서티 122.10
# | 에폭 4 |  반복 641 / 1327 | 시간 853[s] | 퍼플렉서티 111.37
# | 에폭 4 |  반복 661 / 1327 | 시간 856[s] | 퍼플렉서티 102.02
# | 에폭 4 |  반복 681 / 1327 | 시간 860[s] | 퍼플렉서티 83.99
# | 에폭 4 |  반복 701 / 1327 | 시간 864[s] | 퍼플렉서티 101.86
# | 에폭 4 |  반복 721 / 1327 | 시간 868[s] | 퍼플렉서티 107.74
# | 에폭 4 |  반복 741 / 1327 | 시간 871[s] | 퍼플렉서티 94.93
# | 에폭 4 |  반복 761 / 1327 | 시간 875[s] | 퍼플렉서티 87.95
# | 에폭 4 |  반복 781 / 1327 | 시간 879[s] | 퍼플렉서티 87.39
# | 에폭 4 |  반복 801 / 1327 | 시간 883[s] | 퍼플렉서티 97.86
# | 에폭 4 |  반복 821 / 1327 | 시간 887[s] | 퍼플렉서티 101.70
# | 에폭 4 |  반복 841 / 1327 | 시간 891[s] | 퍼플렉서티 98.81
# | 에폭 4 |  반복 861 / 1327 | 시간 895[s] | 퍼플렉서티 103.59
# | 에폭 4 |  반복 881 / 1327 | 시간 898[s] | 퍼플렉서티 91.58
# | 에폭 4 |  반복 901 / 1327 | 시간 902[s] | 퍼플렉서티 115.38
# | 에폭 4 |  반복 921 / 1327 | 시간 906[s] | 퍼플렉서티 102.10
# | 에폭 4 |  반복 941 / 1327 | 시간 909[s] | 퍼플렉서티 111.41
# | 에폭 4 |  반복 961 / 1327 | 시간 913[s] | 퍼플렉서티 112.55
# | 에폭 4 |  반복 981 / 1327 | 시간 917[s] | 퍼플렉서티 107.07
# | 에폭 4 |  반복 1001 / 1327 | 시간 921[s] | 퍼플렉서티 98.04
# | 에폭 4 |  반복 1021 / 1327 | 시간 924[s] | 퍼플렉서티 112.15
# | 에폭 4 |  반복 1041 / 1327 | 시간 928[s] | 퍼플렉서티 104.68
# | 에폭 4 |  반복 1061 / 1327 | 시간 932[s] | 퍼플렉서티 88.27
# | 에폭 4 |  반복 1081 / 1327 | 시간 936[s] | 퍼플렉서티 78.53
# | 에폭 4 |  반복 1101 / 1327 | 시간 939[s] | 퍼플렉서티 78.38
# | 에폭 4 |  반복 1121 / 1327 | 시간 943[s] | 퍼플렉서티 102.51
# | 에폭 4 |  반복 1141 / 1327 | 시간 947[s] | 퍼플렉서티 99.62
# | 에폭 4 |  반복 1161 / 1327 | 시간 951[s] | 퍼플렉서티 93.29
# | 에폭 4 |  반복 1181 / 1327 | 시간 954[s] | 퍼플렉서티 96.64
# | 에폭 4 |  반복 1201 / 1327 | 시간 958[s] | 퍼플렉서티 82.87
# | 에폭 4 |  반복 1221 / 1327 | 시간 962[s] | 퍼플렉서티 75.64
# | 에폭 4 |  반복 1241 / 1327 | 시간 966[s] | 퍼플렉서티 90.79
# | 에폭 4 |  반복 1261 / 1327 | 시간 970[s] | 퍼플렉서티 93.11
# | 에폭 4 |  반복 1281 / 1327 | 시간 973[s] | 퍼플렉서티 89.10
# | 에폭 4 |  반복 1301 / 1327 | 시간 977[s] | 퍼플렉서티 109.72
# | 에폭 4 |  반복 1321 / 1327 | 시간 981[s] | 퍼플렉서티 108.49
# | 에폭 5 |  반복 1 / 1327 | 시간 982[s] | 퍼플렉서티 120.22
# | 에폭 5 |  반복 21 / 1327 | 시간 986[s] | 퍼플렉서티 107.29
# | 에폭 5 |  반복 41 / 1327 | 시간 990[s] | 퍼플렉서티 92.53
# | 에폭 5 |  반복 61 / 1327 | 시간 993[s] | 퍼플렉서티 94.34
# | 에폭 5 |  반복 81 / 1327 | 시간 997[s] | 퍼플렉서티 84.84
# | 에폭 5 |  반복 101 / 1327 | 시간 1001[s] | 퍼플렉서티 75.67
# | 에폭 5 |  반복 121 / 1327 | 시간 1005[s] | 퍼플렉서티 84.69
# | 에폭 5 |  반복 141 / 1327 | 시간 1008[s] | 퍼플렉서티 88.44
# | 에폭 5 |  반복 161 / 1327 | 시간 1012[s] | 퍼플렉서티 104.54
# | 에폭 5 |  반복 181 / 1327 | 시간 1016[s] | 퍼플렉서티 113.25
# | 에폭 5 |  반복 201 / 1327 | 시간 1020[s] | 퍼플렉서티 108.82
# | 에폭 5 |  반복 221 / 1327 | 시간 1023[s] | 퍼플렉서티 109.85
# | 에폭 5 |  반복 241 / 1327 | 시간 1027[s] | 퍼플렉서티 100.59
# | 에폭 5 |  반복 261 / 1327 | 시간 1031[s] | 퍼플렉서티 101.33
# | 에폭 5 |  반복 281 / 1327 | 시간 1035[s] | 퍼플렉서티 107.37
# | 에폭 5 |  반복 301 / 1327 | 시간 1038[s] | 퍼플렉서티 92.32
# | 에폭 5 |  반복 321 / 1327 | 시간 1042[s] | 퍼플렉서티 75.46
# | 에폭 5 |  반복 341 / 1327 | 시간 1046[s] | 퍼플렉서티 89.01
# | 에폭 5 |  반복 361 / 1327 | 시간 1049[s] | 퍼플렉서티 113.97
# | 에폭 5 |  반복 381 / 1327 | 시간 1053[s] | 퍼플렉서티 87.08
# | 에폭 5 |  반복 401 / 1327 | 시간 1057[s] | 퍼플렉서티 96.41
# | 에폭 5 |  반복 421 / 1327 | 시간 1061[s] | 퍼플렉서티 84.81
# | 에폭 5 |  반복 441 / 1327 | 시간 1064[s] | 퍼플렉서티 91.55
# | 에폭 5 |  반복 461 / 1327 | 시간 1068[s] | 퍼플렉서티 87.90
# | 에폭 5 |  반복 481 / 1327 | 시간 1072[s] | 퍼플렉서티 90.78
# | 에폭 5 |  반복 501 / 1327 | 시간 1076[s] | 퍼플렉서티 96.98
# | 에폭 5 |  반복 521 / 1327 | 시간 1079[s] | 퍼플렉서티 106.21
# | 에폭 5 |  반복 541 / 1327 | 시간 1083[s] | 퍼플렉서티 96.92
# | 에폭 5 |  반복 561 / 1327 | 시간 1087[s] | 퍼플렉서티 93.13
# | 에폭 5 |  반복 581 / 1327 | 시간 1090[s] | 퍼플렉서티 79.95
# | 에폭 5 |  반복 601 / 1327 | 시간 1094[s] | 퍼플렉서티 111.46
# | 에폭 5 |  반복 621 / 1327 | 시간 1098[s] | 퍼플렉서티 109.98
# | 에폭 5 |  반복 641 / 1327 | 시간 1102[s] | 퍼플렉서티 100.87
# | 에폭 5 |  반복 661 / 1327 | 시간 1105[s] | 퍼플렉서티 90.09
# | 에폭 5 |  반복 681 / 1327 | 시간 1109[s] | 퍼플렉서티 74.88
# | 에폭 5 |  반복 701 / 1327 | 시간 1113[s] | 퍼플렉서티 92.62
# | 에폭 5 |  반복 721 / 1327 | 시간 1117[s] | 퍼플렉서티 95.18
# | 에폭 5 |  반복 741 / 1327 | 시간 1120[s] | 퍼플렉서티 86.30
# | 에폭 5 |  반복 761 / 1327 | 시간 1124[s] | 퍼플렉서티 80.14
# | 에폭 5 |  반복 781 / 1327 | 시간 1128[s] | 퍼플렉서티 77.17
# | 에폭 5 |  반복 801 / 1327 | 시간 1132[s] | 퍼플렉서티 88.46
# | 에폭 5 |  반복 821 / 1327 | 시간 1135[s] | 퍼플렉서티 91.74
# | 에폭 5 |  반복 841 / 1327 | 시간 1139[s] | 퍼플렉서티 88.21
# | 에폭 5 |  반복 861 / 1327 | 시간 1143[s] | 퍼플렉서티 94.53
# | 에폭 5 |  반복 881 / 1327 | 시간 1146[s] | 퍼플렉서티 83.14
# | 에폭 5 |  반복 901 / 1327 | 시간 1150[s] | 퍼플렉서티 103.24
# | 에폭 5 |  반복 921 / 1327 | 시간 1154[s] | 퍼플렉서티 92.83
# | 에폭 5 |  반복 941 / 1327 | 시간 1158[s] | 퍼플렉서티 100.22
# | 에폭 5 |  반복 961 / 1327 | 시간 1161[s] | 퍼플렉서티 102.08
# | 에폭 5 |  반복 981 / 1327 | 시간 1165[s] | 퍼플렉서티 98.22
# | 에폭 5 |  반복 1001 / 1327 | 시간 1169[s] | 퍼플렉서티 89.80
# | 에폭 5 |  반복 1021 / 1327 | 시간 1173[s] | 퍼플렉서티 102.72
# | 에폭 5 |  반복 1041 / 1327 | 시간 1176[s] | 퍼플렉서티 93.73
# | 에폭 5 |  반복 1061 / 1327 | 시간 1180[s] | 퍼플렉서티 79.90
# | 에폭 5 |  반복 1081 / 1327 | 시간 1184[s] | 퍼플렉서티 71.23
# | 에폭 5 |  반복 1101 / 1327 | 시간 1188[s] | 퍼플렉서티 71.27
# | 에폭 5 |  반복 1121 / 1327 | 시간 1192[s] | 퍼플렉서티 90.93
# | 에폭 5 |  반복 1141 / 1327 | 시간 1195[s] | 퍼플렉서티 92.10
# | 에폭 5 |  반복 1161 / 1327 | 시간 1199[s] | 퍼플렉서티 83.56
# | 에폭 5 |  반복 1181 / 1327 | 시간 1203[s] | 퍼플렉서티 88.60
# | 에폭 5 |  반복 1201 / 1327 | 시간 1206[s] | 퍼플렉서티 76.36
# | 에폭 5 |  반복 1221 / 1327 | 시간 1210[s] | 퍼플렉서티 67.14
# | 에폭 5 |  반복 1241 / 1327 | 시간 1214[s] | 퍼플렉서티 82.45
# | 에폭 5 |  반복 1261 / 1327 | 시간 1218[s] | 퍼플렉서티 85.79
# | 에폭 5 |  반복 1281 / 1327 | 시간 1221[s] | 퍼플렉서티 79.35
# | 에폭 5 |  반복 1301 / 1327 | 시간 1225[s] | 퍼플렉서티 100.62
# | 에폭 5 |  반복 1321 / 1327 | 시간 1229[s] | 퍼플렉서티 99.68
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47113 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54540 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47113 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/h/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# 퍼플렉서티 평가 중 ...
# 234 / 235
# test perplexity:  138.08281578085672
